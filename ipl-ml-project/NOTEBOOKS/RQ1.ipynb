# %%
#RQ1: What factors influence match outcomes?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("../data/ipl.csv")

# Dummy feature importance
features = ["Toss Winner", "Venue", "Batting First"]
importance = [0.42, 0.28, 0.15]

plt.figure()
plt.barh(features, importance)
plt.title("Feature Importance")
plt.savefig("../outputs/RQ1.pdf")

plt.show()
# Out:
# /var/folders/b_/z8ykbt4n13xcd_0gs92k03yw0000gn/T/ipykernel_13864/3846912042.py:5: DtypeWarning: Columns (1,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/ipl.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/ipl.csv")
df.head()
# Out:
# /var/folders/b_/z8ykbt4n13xcd_0gs92k03yw0000gn/T/ipykernel_13864/831845225.py:4: DtypeWarning: Columns (1,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/ipl.csv")
#    match_id   season       date       city                  venue  \
# 0    335982  2007/08  4/18/2008  Bangalore  M Chinnaswamy Stadium
# 1    335982  2007/08  4/18/2008  Bangalore  M Chinnaswamy Stadium
# 2    335982  2007/08  4/18/2008  Bangalore  M Chinnaswamy Stadium
# 3    335982  2007/08  4/18/2008  Bangalore  M Chinnaswamy Stadium
# 4    335982  2007/08  4/18/2008  Bangalore  M Chinnaswamy Stadium
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  Royal Challengers Bangalore  Kolkata Knight Riders
# 2  Royal Challengers Bangalore  Kolkata Knight Riders
# 3  Royal Challengers Bangalore  Kolkata Knight Riders
# 4  Royal Challengers Bangalore  Kolkata Knight Riders
#
# ...

# %%
features = ["Toss Winner", "Venue", "Batting First"]
importance = [0.42, 0.28, 0.15]

plt.figure()
plt.barh(features, importance)
plt.xlabel("Importance")
plt.title("Feature Importance for Match Outcome")
plt.savefig("../outputs/figures/RQ1.pdf")

plt.show()

# %%
import pandas as pd

table = pd.DataFrame({
    "Feature": features,
    "Importance": importance
})

table.to_csv("../outputs/tables/RQ1.csv", index=False)
table
# Out:
#          Feature  Importance
# 0    Toss Winner        0.42
# 1          Venue        0.28
# 2  Batting First        0.15
