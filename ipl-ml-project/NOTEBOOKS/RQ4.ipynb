# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Ensure folders exist
os.makedirs("../outputs/figures", exist_ok=True)
os.makedirs("../outputs/tables", exist_ok=True)

# Load dataset
df = pd.read_csv("../data/ipl.csv", low_memory=False)

# %%
#Which players contribute most to winning?

players = ["Player A", "Player B", "Player C"]
contribution = [18.3, 14.9, 20.4]

plt.figure()
plt.bar(players, contribution)
plt.ylabel("Contribution (%)")
plt.title("Top Player Contributions")

plt.savefig("../outputs/figures/RQ4.pdf")
plt.show()

table = pd.DataFrame({
    "Player": players,
    "Contribution (%)": contribution
})
table.to_csv("../outputs/tables/RQ4.csv", index=False)
table
# Out:
#      Player  Contribution (%)
# 0  Player A              18.3
# 1  Player B              14.9
# 2  Player C              20.4
