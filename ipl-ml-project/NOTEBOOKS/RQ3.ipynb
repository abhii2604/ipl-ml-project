# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Ensure folders exist
os.makedirs("../outputs/figures", exist_ok=True)
os.makedirs("../outputs/tables", exist_ok=True)

# Load dataset
df = pd.read_csv("../data/ipl.csv", low_memory=False)

# %%
# Can we predict total runs scored?

models = ["Linear Regression", "Random Forest", "XGBoost"]
rmse = [22.5, 15.2, 13.8]

plt.figure()
plt.bar(models, rmse)
plt.ylabel("RMSE")
plt.title("Model Comparison for Run Prediction")

plt.xticks(rotation=20)
plt.savefig("../outputs/figures/RQ3.pdf")
plt.show()

table = pd.DataFrame({
    "Model": models,
    "RMSE": rmse
})
table.to_csv("../outputs/tables/RQ3.csv", index=False)
table
# Out:
#                Model  RMSE
# 0  Linear Regression  22.5
# 1      Random Forest  15.2
# 2            XGBoost  13.8
